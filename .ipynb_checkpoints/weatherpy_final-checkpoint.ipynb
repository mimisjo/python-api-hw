# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 599

# %%
# Create a data frame from cities list
cities_dict = {
    "city": cities,
    "country": countries
    }

weather_df = pd.DataFrame(cities_dict)

# Add columns
weather_df["id"] = ""
weather_df["latitude"] = ""
weather_df["longitude"] = ""
weather_df["temp_f"] = ""
weather_df["humidity"] = ""
weather_df["cloudiness"] = ""
weather_df["wind_speed"] = ""
weather_df["date"] = ""

weather_df.head()
# Out:
#              city country id latitude longitude temp_f humidity cloudiness  \
# 0             oda      jp
# 1  kumylzhenskaya      ru
# 2            mana      gf
# 3          avarua      ck
# 4       cape town      za
#
#   wind_speed date
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# create a params dict that will be updated with new city each iteration
units = "imperial"

params = {
    'appid': api_key,
    'units': units
}

# Loop through weather_df and run a data search for each city
for index, row in weather_df.iterrows():
    base_url = "https://api.openweathermap.org/data/2.5/weather"

    city = row['city']
    country = row['country']

    # update address key value
    params['q'] = f"{city},{country}"

    # make request
    print(f"Retrieving results for {city}, {country} (country code).")
    weather_response = requests.get(base_url, params)
    
    # print the weather_response url, avoid doing for public github repos in order to avoid exposing key
    # print(weather_response.url)
    
    # convert to json
    weather_response = weather_response.json()

    # pull data from api
    try:
        print(f"City id number: {weather_response['id']}.")
        
        weather_df.loc[index, "id"] = weather_response['id']
        weather_df.loc[index, "latitude"] = weather_response['coord']['lat']
        weather_df.loc[index, "longitude"] = weather_response['coord']['lon']
        weather_df.loc[index, "temp_f"] = weather_response['main']['temp']
        weather_df.loc[index, "humidity"] = weather_response['main']['humidity']
        weather_df.loc[index, "cloudiness"] = weather_response['clouds']['all']
        weather_df.loc[index, "wind_speed"] = weather_response['wind']['speed']
        weather_df.loc[index, "date"] = weather_response['dt']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
    
    print("------------")
#     break
# Out:
# Retrieving results for oda, jp (country code).
# City id number: 1854774.
# ------------
# Retrieving results for kumylzhenskaya, ru (country code).
# City id number: 539221.
# ------------
# Retrieving results for mana, gf (country code).
# City id number: 3381041.
# ------------
# Retrieving results for avarua, ck (country code).
# City id number: 4035715.
# ------------
# Retrieving results for cape town, za (country code).
# City id number: 3369157.
# ------------
# Retrieving results for tasiilaq, gl (country code).
# City id number: 3424607.
# ------------
# Retrieving results for cesis, lv (country code).
# City id number: 460570.
# ------------
# Retrieving results for domoni, km (country code).
# City id number: 921906.
# ------------
# Retrieving results for bairiki, ki (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for ribeira grande, pt (country code).
# City id number: 3372707.
# ------------
# Retrieving results for kapaa, us (country code).
# City id number: 5848280.
# ------------
# Retrieving results for vaini, to (country code).
# City id number: 4032243.
# ------------
# Retrieving results for rikitea, pf (country code).
# City id number: 4030556.
# ------------
# Retrieving results for moyale, et (country code).
# City id number: 186180.
# ------------
# Retrieving results for portland, au (country code).
# City id number: 2152668.
# ------------
# Retrieving results for albany, au (country code).
# City id number: 2077963.
# ------------
# Retrieving results for aloleng, ph (country code).
# City id number: 1731298.
# ------------
# Retrieving results for qaanaaq, gl (country code).
# City id number: 3831208.
# ------------
# Retrieving results for port elizabeth, za (country code).
# City id number: 964420.
# ------------
# Retrieving results for huarmey, pe (country code).
# City id number: 3939168.
# ------------
# Retrieving results for kavieng, pg (country code).
# City id number: 2094342.
# ------------
# Retrieving results for bluff, nz (country code).
# City id number: 2206939.
# ------------
# Retrieving results for rungata, ki (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for punta arenas, cl (country code).
# City id number: 3874787.
# ------------
# Retrieving results for the valley, ai (country code).
# City id number: 3573374.
# ------------
# Retrieving results for newport, us (country code).
# City id number: 5223593.
# ------------
# Retrieving results for illoqqortoormiut, gl (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for bintulu, my (country code).
# City id number: 1737486.
# ------------
# Retrieving results for provideniya, ru (country code).
# City id number: 4031574.
# ------------
# Retrieving results for gat, ly (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for busselton, au (country code).
# City id number: 2075265.
# ------------
# Retrieving results for tomatlan, mx (country code).
# City id number: 3981391.
# ------------
# Retrieving results for barentsburg, sj (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for faya, td (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for shache, cn (country code).
# City id number: 1280037.
# ------------
# Retrieving results for manati, cu (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for palabuhanratu, id (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for winnemucca, us (country code).
# City id number: 5710360.
# ------------
# Retrieving results for vao, nc (country code).
# City id number: 2137773.
# ------------
# Retrieving results for caravelas, br (country code).
# City id number: 3466980.
# ------------
# Retrieving results for guerrero negro, mx (country code).
# City id number: 4021858.
# ------------
# Retrieving results for westport, ie (country code).
# City id number: 2960970.
# ------------
# Retrieving results for nuevo progreso, mx (country code).
# City id number: 3522013.
# ------------
# Retrieving results for kaitangata, nz (country code).
# City id number: 2208248.
# ------------
# Retrieving results for tsihombe, mg (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for barrow, us (country code).
# City id number: 4252975.
# ------------
# Retrieving results for dolores, ar (country code).
# City id number: 3435038.
# ------------
# Retrieving results for hobart, au (country code).
# City id number: 2163355.
# ------------
# Retrieving results for vidim, ru (country code).
# City id number: 2013406.
# ------------
# Retrieving results for ponta do sol, cv (country code).
# City id number: 3374346.
# ------------
# Retrieving results for okha, ru (country code).
# City id number: 2122614.
# ------------
# Retrieving results for torbay, ca (country code).
# City id number: 6167817.
# ------------
# Retrieving results for broome, au (country code).
# City id number: 2075720.
# ------------
# Retrieving results for georgetown, sh (country code).
# City id number: 2411397.
# ------------
# Retrieving results for thompson, ca (country code).
# City id number: 6165406.
# ------------
# Retrieving results for yellowknife, ca (country code).
# City id number: 6185377.
# ------------
# Retrieving results for tuktoyaktuk, ca (country code).
# City id number: 6170031.
# ------------
# Retrieving results for ushuaia, ar (country code).
# City id number: 3833367.
# ------------
# Retrieving results for marquette, us (country code).
# City id number: 5000947.
# ------------
# Retrieving results for inirida, co (country code).
# City id number: 3671450.
# ------------
# Retrieving results for amderma, ru (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for warqla, dz (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for yulara, au (country code).
# City id number: 6355222.
# ------------
# Retrieving results for dzerzhinsk, by (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for cap malheureux, mu (country code).
# City id number: 934649.
# ------------
# Retrieving results for bethel, us (country code).
# City id number: 5880568.
# ------------
# Retrieving results for san ramon, bo (country code).
# City id number: 3905088.
# ------------
# Retrieving results for hermanus, za (country code).
# City id number: 3366880.
# ------------
# Retrieving results for margate, za (country code).
# City id number: 978895.
# ------------
# Retrieving results for lebu, cl (country code).
# City id number: 3883457.
# ------------
# Retrieving results for taolanaro, mg (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for mount isa, au (country code).
# City id number: 2065594.
# ------------
# Retrieving results for geraldton, au (country code).
# City id number: 2070998.
# ------------
# Retrieving results for udachnyy, ru (country code).
# City id number: 2014624.
# ------------
# Retrieving results for new norfolk, au (country code).
# City id number: 2155415.
# ------------
# Retrieving results for hilo, us (country code).
# City id number: 5855927.
# ------------
# Retrieving results for pisco, pe (country code).
# City id number: 3932145.
# ------------
# Retrieving results for tumannyy, ru (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for manzanillo, mx (country code).
# City id number: 3996663.
# ------------
# Retrieving results for jamestown, sh (country code).
# City id number: 3370903.
# ------------
# Retrieving results for tevaitoa, pf (country code).
# City id number: 4033375.
# ------------
# Retrieving results for tasbuget, kz (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for husavik, is (country code).
# City id number: 2629833.
# ------------
# Retrieving results for cabo san lucas, mx (country code).
# City id number: 3985710.
# ------------
# Retrieving results for aleksandrovka, ru (country code).
# City id number: 558799.
# ------------
# Retrieving results for ushibuka, jp (country code).
# City id number: 1849154.
# ------------
# Retrieving results for nanortalik, gl (country code).
# City id number: 3421765.
# ------------
# Retrieving results for riverton, nz (country code).
# City id number: 2206957.
# ------------
# Retrieving results for lagoa, pt (country code).
# City id number: 2267254.
# ------------
# Retrieving results for humberto de campos, br (country code).
# City id number: 3398428.
# ------------
# Retrieving results for olinda, br (country code).
# City id number: 3456160.
# ------------
# Retrieving results for cherskiy, ru (country code).
# City id number: 2126199.
# ------------
# Retrieving results for lata, sb (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for svetlogorsk, ru (country code).
# City id number: 584051.
# ------------
# Retrieving results for am timan, td (country code).
# City id number: 245338.
# ------------
# Retrieving results for komsomolskiy, ru (country code).
# City id number: 1486910.
# ------------
# Retrieving results for msowero, tz (country code).
# City id number: 152933.
# ------------
# Retrieving results for mahebourg, mu (country code).
# City id number: 934322.
# ------------
# Retrieving results for mataura, pf (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for alofi, nu (country code).
# City id number: 4036284.
# ------------
# Retrieving results for kirakira, sb (country code).
# City id number: 2178753.
# ------------
# Retrieving results for sayla, in (country code).
# City id number: 1256929.
# ------------
# Retrieving results for karratha, au (country code).
# City id number: 6620339.
# ------------
# Retrieving results for atuona, pf (country code).
# City id number: 4020109.
# ------------
# Retrieving results for puerto ayora, ec (country code).
# City id number: 3652764.
# ------------
# Retrieving results for ahipara, nz (country code).
# City id number: 2194098.
# ------------
# Retrieving results for emerald, au (country code).
# City id number: 2167426.
# ------------
# Retrieving results for stony plain, ca (country code).
# City id number: 6157536.
# ------------
# Retrieving results for hithadhoo, mv (country code).
# City id number: 1282256.
# ------------
# Retrieving results for mayo, ca (country code).
# City id number: 6068416.
# ------------
# Retrieving results for wukari, ng (country code).
# City id number: 2318921.
# ------------
# Retrieving results for warrington, us (country code).
# City id number: 5205788.
# ------------
# Retrieving results for port blair, in (country code).
# City id number: 1259385.
# ------------
# Retrieving results for pochutla, mx (country code).
# City id number: 3517970.
# ------------
# Retrieving results for umzimvubu, za (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for berlevag, no (country code).
# City id number: 780687.
# ------------
# Retrieving results for beni suef, eg (country code).
# City id number: 359173.
# ------------
# Retrieving results for saldanha, za (country code).
# City id number: 3361934.
# ------------
# Retrieving results for chuy, uy (country code).
# City id number: 3443061.
# ------------
# Retrieving results for tuatapere, nz (country code).
# City id number: 2180815.
# ------------
# Retrieving results for avera, pf (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for wanning, cn (country code).
# City id number: 1791779.
# ------------
# Retrieving results for codrington, ag (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for mareeba, au (country code).
# City id number: 2158767.
# ------------
# Retrieving results for eyl, so (country code).
# City id number: 60019.
# ------------
# Retrieving results for vila velha, br (country code).
# City id number: 6320062.
# ------------
# Retrieving results for sao filipe, cv (country code).
# City id number: 3374210.
# ------------
# Retrieving results for mumbwa, zm (country code).
# City id number: 904422.
# ------------
# Retrieving results for sentyabrskiy, ru (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for lompoc, us (country code).
# City id number: 5367788.
# ------------
# Retrieving results for namatanai, pg (country code).
# City id number: 2090021.
# ------------
# Retrieving results for kuala terengganu, my (country code).
# City id number: 1734705.
# ------------
# Retrieving results for kharp, ru (country code).
# City id number: 1503726.
# ------------
# Retrieving results for castro, cl (country code).
# City id number: 3896218.
# ------------
# Retrieving results for aasiaat, gl (country code).
# City id number: 3424901.
# ------------
# Retrieving results for skalistyy, ru (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for iguape, br (country code).
# City id number: 3461465.
# ------------
# Retrieving results for lolua, tv (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for yerbogachen, ru (country code).
# City id number: 2012956.
# ------------
# Retrieving results for airai, pw (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for okhotsk, ru (country code).
# City id number: 2122605.
# ------------
# Retrieving results for arraial do cabo, br (country code).
# City id number: 3471451.
# ------------
# Retrieving results for onguday, ru (country code).
# City id number: 1496130.
# ------------
# Retrieving results for narsaq, gl (country code).
# City id number: 3421719.
# ------------
# Retrieving results for caiaponia, br (country code).
# City id number: 3468234.
# ------------
# Retrieving results for bredasdorp, za (country code).
# City id number: 1015776.
# ------------
# Retrieving results for whitianga, nz (country code).
# City id number: 2179103.
# ------------
# Retrieving results for san patricio, mx (country code).
# City id number: 3985168.
# ------------
# Retrieving results for makakilo city, us (country code).
# City id number: 5850554.
# ------------
# Retrieving results for saint george, bm (country code).
# City id number: 3573061.
# ------------
# Retrieving results for gayny, ru (country code).
# City id number: 561698.
# ------------
# Retrieving results for virginia beach, us (country code).
# City id number: 4791259.
# ------------
# Retrieving results for pitimbu, br (country code).
# City id number: 3391889.
# ------------
# Retrieving results for vallenar, cl (country code).
# City id number: 3868633.
# ------------
# Retrieving results for nikolskoye, ru (country code).
# City id number: 546105.
# ------------
# Retrieving results for saskylakh, ru (country code).
# City id number: 2017155.
# ------------
# Retrieving results for tessalit, ml (country code).
# City id number: 2449893.
# ------------
# Retrieving results for axim, gh (country code).
# City id number: 2303611.
# ------------
# Retrieving results for camopi, gf (country code).
# City id number: 3382226.
# ------------
# Retrieving results for bengkulu, id (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for inuvik, ca (country code).
# City id number: 5983607.
# ------------
# Retrieving results for abu samrah, qa (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for ancud, cl (country code).
# City id number: 3899695.
# ------------
# Retrieving results for tubruq, ly (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for agbor, ng (country code).
# City id number: 2351979.
# ------------
# Retrieving results for grindavik, is (country code).
# City id number: 3416888.
# ------------
# Retrieving results for grand gaube, mu (country code).
# City id number: 934479.
# ------------
# Retrieving results for wad rawah, sd (country code).
# City id number: 364071.
# ------------
# Retrieving results for marsa matruh, eg (country code).
# City id number: 352733.
# ------------
# Retrieving results for norman wells, ca (country code).
# City id number: 6089245.
# ------------
# Retrieving results for waingapu, id (country code).
# City id number: 1622318.
# ------------
# Retrieving results for sociedad, sv (country code).
# City id number: 3583111.
# ------------
# Retrieving results for katsuura, jp (country code).
# City id number: 1865309.
# ------------
# Retrieving results for hamilton, us (country code).
# City id number: 5655959.
# ------------
# Retrieving results for mountain home, us (country code).
# City id number: 5601615.
# ------------
# Retrieving results for nemuro, jp (country code).
# City id number: 2128975.
# ------------
# Retrieving results for olafsvik, is (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for satitoa, ws (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for atar, mr (country code).
# City id number: 2381334.
# ------------
# Retrieving results for kloulklubed, pw (country code).
# City id number: 7671223.
# ------------
# Retrieving results for cururupu, br (country code).
# City id number: 3401148.
# ------------
# Retrieving results for ginda, er (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for carberry, ca (country code).
# City id number: 5916706.
# ------------
# Retrieving results for coquimbo, cl (country code).
# City id number: 3893629.
# ------------
# Retrieving results for mayumba, ga (country code).
# City id number: 2399001.
# ------------
# Retrieving results for fort nelson, ca (country code).
# City id number: 5955902.
# ------------
# Retrieving results for upernavik, gl (country code).
# City id number: 3418910.
# ------------
# Retrieving results for fort wellington, gy (country code).
# City id number: 3378690.
# ------------
# Retrieving results for srednekolymsk, ru (country code).
# City id number: 2121025.
# ------------
# Retrieving results for belushya guba, ru (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for kralendijk, an (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for carnarvon, au (country code).
# City id number: 2074865.
# ------------
# Retrieving results for sao joao da barra, br (country code).
# City id number: 3448903.
# ------------
# Retrieving results for pedregal, pa (country code).
# City id number: 3703229.
# ------------
# Retrieving results for bitkine, td (country code).
# City id number: 2435124.
# ------------
# Retrieving results for kamenskoye, ru (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for bongaree, au (country code).
# City id number: 2174933.
# ------------
# Retrieving results for taoudenni, ml (country code).
# City id number: 2450173.
# ------------
# Retrieving results for los llanos de aridane, es (country code).
# City id number: 2514651.
# ------------
# Retrieving results for mount gambier, au (country code).
# City id number: 2156643.
# ------------
# Retrieving results for rio gallegos, ar (country code).
# City id number: 3838859.
# ------------
# Retrieving results for saint-augustin, ca (country code).
# City id number: 6138501.
# ------------
# Retrieving results for praia, cv (country code).
# City id number: 3374333.
# ------------
# Retrieving results for leningradskiy, ru (country code).
# City id number: 2123814.
# ------------
# Retrieving results for buala, sb (country code).
# City id number: 2109528.
# ------------
# Retrieving results for luderitz, na (country code).
# City id number: 3355672.
# ------------
# Retrieving results for panguipulli, cl (country code).
# City id number: 3877348.
# ------------
# Retrieving results for reo, bf (country code).
# City id number: 2356228.
# ------------
# Retrieving results for atherton, au (country code).
# City id number: 2177541.
# ------------
# Retrieving results for poum, nc (country code).
# City id number: 2138555.
# ------------
# Retrieving results for tiksi, ru (country code).
# City id number: 2015306.
# ------------
# Retrieving results for usinsk, ru (country code).
# City id number: 863061.
# ------------
# Retrieving results for kieta, pg (country code).
# City id number: 2094027.
# ------------
# Retrieving results for esperance, au (country code).
# City id number: 2071860.
# ------------
# Retrieving results for mys shmidta, ru (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for ozernovskiy, ru (country code).
# City id number: 2122293.
# ------------
# Retrieving results for kokopo, pg (country code).
# City id number: 2093685.
# ------------
# Retrieving results for saryshagan, kz (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for mar del plata, ar (country code).
# City id number: 3863379.
# ------------
# Retrieving results for mehamn, no (country code).
# City id number: 778707.
# ------------
# Retrieving results for amapa, br (country code).
# City id number: 3401225.
# ------------
# Retrieving results for doha, qa (country code).
# City id number: 290030.
# ------------
# Retrieving results for gulu, ug (country code).
# City id number: 233346.
# ------------
# Retrieving results for chokurdakh, ru (country code).
# City id number: 2126123.
# ------------
# Retrieving results for minot, us (country code).
# City id number: 5690532.
# ------------
# Retrieving results for nhulunbuy, au (country code).
# City id number: 2064735.
# ------------
# Retrieving results for najran, sa (country code).
# City id number: 103630.
# ------------
# Retrieving results for souillac, mu (country code).
# City id number: 933995.
# ------------
# Retrieving results for santo tomas, pe (country code).
# City id number: 3696183.
# ------------
# Retrieving results for emba, kz (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for yuancheng, cn (country code).
# City id number: 1786110.
# ------------
# Retrieving results for kropotkin, ru (country code).
# City id number: 540761.
# ------------
# Retrieving results for mananara, mg (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for la rioja, ar (country code).
# City id number: 3848950.
# ------------
# Retrieving results for saint-philippe, re (country code).
# City id number: 935215.
# ------------
# Retrieving results for roma, au (country code).
# City id number: 2151187.
# ------------
# Retrieving results for gold coast, au (country code).
# City id number: 2165087.
# ------------
# Retrieving results for dikson, ru (country code).
# City id number: 1507390.
# ------------
# Retrieving results for pevek, ru (country code).
# City id number: 2122090.
# ------------
# Retrieving results for haibowan, cn (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for butaritari, ki (country code).
# City id number: 2110227.
# ------------
# Retrieving results for mizan teferi, et (country code).
# City id number: 330534.
# ------------
# Retrieving results for kavaratti, in (country code).
# City id number: 1267390.
# ------------
# Retrieving results for teguldet, ru (country code).
# City id number: 1489822.
# ------------
# Retrieving results for zhigansk, ru (country code).
# City id number: 2012530.
# ------------
# Retrieving results for shubarshi, kz (country code).
# City id number: 608270.
# ------------
# Retrieving results for isla mujeres, mx (country code).
# City id number: 3526756.
# ------------
# Retrieving results for kulhudhuffushi, mv (country code).
# City id number: 1337613.
# ------------
# Retrieving results for carbonear, ca (country code).
# City id number: 5916722.
# ------------
# Retrieving results for paciran, id (country code).
# City id number: 1633442.
# ------------
# Retrieving results for port alfred, za (country code).
# City id number: 964432.
# ------------
# Retrieving results for yarada, in (country code).
# City id number: 1252783.
# ------------
# Retrieving results for haines junction, ca (country code).
# City id number: 5969025.
# ------------
# Retrieving results for bileca, ba (country code).
# City id number: 3204161.
# ------------
# Retrieving results for split, hr (country code).
# City id number: 3190261.
# ------------
# Retrieving results for bereda, so (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for necochea, ar (country code).
# City id number: 3430443.
# ------------
# Retrieving results for wuning, cn (country code).
# City id number: 7071576.
# ------------
# Retrieving results for graciano sanchez, mx (country code).
# City id number: 3527413.
# ------------
# Retrieving results for punta alta, ar (country code).
# City id number: 3429886.
# ------------
# Retrieving results for talnakh, ru (country code).
# City id number: 1490256.
# ------------
# Retrieving results for bauchi, ng (country code).
# City id number: 2347470.
# ------------
# Retrieving results for guanica, us (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for abalak, ne (country code).
# City id number: 2448245.
# ------------
# Retrieving results for east london, za (country code).
# City id number: 1006984.
# ------------
# Retrieving results for ninh binh, vn (country code).
# City id number: 1571968.
# ------------
# Retrieving results for karaton, kz (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for fortuna, us (country code).
# City id number: 5563839.
# ------------
# Retrieving results for prieska, za (country code).
# City id number: 964090.
# ------------
# Retrieving results for bambous virieux, mu (country code).
# City id number: 1106677.
# ------------
# Retrieving results for kuche, cn (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for alice springs, au (country code).
# City id number: 2077895.
# ------------
# Retrieving results for buraydah, sa (country code).
# City id number: 107304.
# ------------
# Retrieving results for kodiak, us (country code).
# City id number: 4407665.
# ------------
# Retrieving results for alta floresta, br (country code).
# City id number: 6316343.
# ------------
# Retrieving results for bar harbor, us (country code).
# City id number: 4957320.
# ------------
# Retrieving results for talaya, ru (country code).
# City id number: 1485724.
# ------------
# Retrieving results for nouakchott, mr (country code).
# City id number: 2377450.
# ------------
# Retrieving results for nha trang, vn (country code).
# City id number: 1572151.
# ------------
# Retrieving results for acajutla, sv (country code).
# City id number: 3587498.
# ------------
# Retrieving results for jatiroto, id (country code).
# City id number: 1631992.
# ------------
# Retrieving results for jining, cn (country code).
# City id number: 1805518.
# ------------
# Retrieving results for nishihara, jp (country code).
# City id number: 1850144.
# ------------
# Retrieving results for turkistan, kz (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for victoria, sc (country code).
# City id number: 241131.
# ------------
# Retrieving results for ha tinh, vn (country code).
# City id number: 1581047.
# ------------
# Retrieving results for mananjary, mg (country code).
# City id number: 1056151.
# ------------
# Retrieving results for boende, cd (country code).
# City id number: 218680.
# ------------
# Retrieving results for maldonado, uy (country code).
# City id number: 3441894.
# ------------
# Retrieving results for severo-kurilsk, ru (country code).
# City id number: 2121385.
# ------------
# Retrieving results for aripuana, br (country code).
# City id number: 3665202.
# ------------
# Retrieving results for fethiye, tr (country code).
# City id number: 314967.
# ------------
# Retrieving results for sur, om (country code).
# City id number: 286245.
# ------------
# Retrieving results for freeport, us (country code).
# City id number: 4893171.
# ------------
# Retrieving results for maneadero, mx (country code).
# City id number: 3996737.
# ------------
# Retrieving results for salalah, om (country code).
# City id number: 286621.
# ------------
# Retrieving results for vila franca do campo, pt (country code).
# City id number: 3372472.
# ------------
# Retrieving results for abha, sa (country code).
# City id number: 110690.
# ------------
# Retrieving results for luan, cn (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for kutum, sd (country code).
# City id number: 371745.
# ------------
# Retrieving results for kahului, us (country code).
# City id number: 5847411.
# ------------
# Retrieving results for trinidad, co (country code).
# City id number: 3666719.
# ------------
# Retrieving results for piranhas, br (country code).
# City id number: 3403344.
# ------------
# Retrieving results for honningsvag, no (country code).
# City id number: 779554.
# ------------
# Retrieving results for san isidro, ph (country code).
# City id number: 1689750.
# ------------
# Retrieving results for ostrovnoy, ru (country code).
# City id number: 556268.
# ------------
# Retrieving results for nekrasovka, ru (country code).
# City id number: 2019388.
# ------------
# Retrieving results for kaniama, cd (country code).
# City id number: 214389.
# ------------
# Retrieving results for beringovskiy, ru (country code).
# City id number: 2126710.
# ------------
# Retrieving results for santa rosalia, mx (country code).
# City id number: 3991622.
# ------------
# Retrieving results for porto walter, br (country code).
# City id number: 3662761.
# ------------
# Retrieving results for thinadhoo, mv (country code).
# City id number: 1337610.
# ------------
# Retrieving results for kazanskaya, ru (country code).
# City id number: 551439.
# ------------
# Retrieving results for paamiut, gl (country code).
# City id number: 3421193.
# ------------
# Retrieving results for havre-saint-pierre, ca (country code).
# City id number: 5972291.
# ------------
# Retrieving results for przasnysz, pl (country code).
# City id number: 761218.
# ------------
# Retrieving results for longyearbyen, sj (country code).
# City id number: 2729907.
# ------------
# Retrieving results for saleaula, ws (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for cockburn town, tc (country code).
# City id number: 3576994.
# ------------
# Retrieving results for vila do maio, cv (country code).
# City id number: 3374120.
# ------------
# Retrieving results for pathein, mm (country code).
# City id number: 1328421.
# ------------
# Retrieving results for saint-pierre, pm (country code).
# City id number: 3424934.
# ------------
# Retrieving results for tuy hoa, vn (country code).
# City id number: 1563281.
# ------------
# Retrieving results for denpasar, id (country code).
# City id number: 1645528.
# ------------
# Retrieving results for kautokeino, no (country code).
# City id number: 779330.
# ------------
# Retrieving results for coahuayana, mx (country code).
# City id number: 3981460.
# ------------
# Retrieving results for cockburn harbour, tc (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for arman, ru (country code).
# City id number: 2127060.
# ------------
# Retrieving results for gusau, ng (country code).
# City id number: 2339937.
# ------------
# Retrieving results for tautira, pf (country code).
# City id number: 4033557.
# ------------
# Retrieving results for glendive, us (country code).
# City id number: 5654391.
# ------------
# Retrieving results for aswan, eg (country code).
# City id number: 359792.
# ------------
# Retrieving results for faanui, pf (country code).
# City id number: 4034551.
# ------------
# Retrieving results for el alto, pe (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for nerchinskiy zavod, ru (country code).
# City id number: 2019323.
# ------------
# Retrieving results for labuhan, id (country code).
# City id number: 1641899.
# ------------
# Retrieving results for sandovo, ru (country code).
# City id number: 498856.
# ------------
# Retrieving results for payo, ph (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for chapais, ca (country code).
# City id number: 5919850.
# ------------
# Retrieving results for san quintin, mx (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for nizhneyansk, ru (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for kawalu, id (country code).
# City id number: 1640902.
# ------------
# Retrieving results for teya, ru (country code).
# City id number: 1489656.
# ------------
# Retrieving results for aleppo, sy (country code).
# City id number: 170063.
# ------------
# Retrieving results for azimur, ma (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for pokhara, np (country code).
# City id number: 1282898.
# ------------
# Retrieving results for visby, se (country code).
# City id number: 2662689.
# ------------
# Retrieving results for baijiantan, cn (country code).
# City id number: 1529626.
# ------------
# Retrieving results for bima, id (country code).
# City id number: 1648759.
# ------------
# Retrieving results for sola, vu (country code).
# City id number: 2134814.
# ------------
# Retrieving results for attawapiskat, ca (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for sorland, no (country code).
# City id number: 3137469.
# ------------
# Retrieving results for belyy yar, ru (country code).
# City id number: 1510377.
# ------------
# Retrieving results for meulaboh, id (country code).
# City id number: 1214488.
# ------------
# Retrieving results for izumo, jp (country code).
# City id number: 1861084.
# ------------
# Retrieving results for jiaojiang, cn (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for port lincoln, au (country code).
# City id number: 2063036.
# ------------
# Retrieving results for viedma, ar (country code).
# City id number: 3832899.
# ------------
# Retrieving results for lincoln, ar (country code).
# City id number: 3846864.
# ------------
# Retrieving results for concordia, br (country code).
# City id number: 3465721.
# ------------
# Retrieving results for pandan, ph (country code).
# City id number: 1695555.
# ------------
# Retrieving results for sept-iles, ca (country code).
# City id number: 6144312.
# ------------
# Retrieving results for tucumcari, us (country code).
# City id number: 5495360.
# ------------
# Retrieving results for takapau, nz (country code).
# City id number: 2181988.
# ------------
# Retrieving results for lavrentiya, ru (country code).
# City id number: 4031637.
# ------------
# Retrieving results for malanje, ao (country code).
# City id number: 2239862.
# ------------
# Retrieving results for berdigestyakh, ru (country code).
# City id number: 2026861.
# ------------
# Retrieving results for antofagasta, cl (country code).
# City id number: 3899539.
# ------------
# Retrieving results for tramore, ie (country code).
# City id number: 2960992.
# ------------
# Retrieving results for jishu, cn (country code).
# City id number: 2036418.
# ------------
# Retrieving results for half moon bay, us (country code).
# City id number: 5354943.
# ------------
# Retrieving results for samusu, ws (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for tripoli, ly (country code).
# City id number: 2210247.
# ------------
# Retrieving results for xiaoweizhai, cn (country code).
# City id number: 1789945.
# ------------
# Retrieving results for las vegas, us (country code).
# City id number: 5506956.
# ------------
# Retrieving results for alto araguaia, br (country code).
# City id number: 3472473.
# ------------
# Retrieving results for vestmannaeyjar, is (country code).
# City id number: 3412093.
# ------------
# Retrieving results for prince george, ca (country code).
# City id number: 6113365.
# ------------
# Retrieving results for jacareacanga, br (country code).
# City id number: 3397763.
# ------------
# Retrieving results for plouzane, fr (country code).
# City id number: 2986626.
# ------------
# Retrieving results for lugovoy, ru (country code).
# City id number: 1498919.
# ------------
# Retrieving results for tura, ru (country code).
# City id number: 2014833.
# ------------
# Retrieving results for montepuez, mz (country code).
# City id number: 1037125.
# ------------
# Retrieving results for brae, gb (country code).
# City id number: 2654970.
# ------------
# Retrieving results for camana, pe (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for hobyo, so (country code).
# City id number: 57000.
# ------------
# Retrieving results for coihaique, cl (country code).
# City id number: 3894426.
# ------------
# Retrieving results for santa cruz de la palma, es (country code).
# City id number: 2511180.
# ------------
# Retrieving results for bideford, gb (country code).
# City id number: 2655707.
# ------------
# Retrieving results for chico, us (country code).
# City id number: 5336269.
# ------------
# Retrieving results for bahar, ir (country code).
# City id number: 142000.
# ------------
# Retrieving results for saint-georges, gf (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for padang, id (country code).
# City id number: 1633419.
# ------------
# Retrieving results for saint anthony, ca (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for ilulissat, gl (country code).
# City id number: 3423146.
# ------------
# Retrieving results for ndele, cf (country code).
# City id number: 237379.
# ------------
# Retrieving results for riviere-au-renard, ca (country code).
# City id number: 6943832.
# ------------
# Retrieving results for erenhot, cn (country code).
# City id number: 2037485.
# ------------
# Retrieving results for mwene-ditu, cd (country code).
# City id number: 207570.
# ------------
# Retrieving results for mackay, au (country code).
# City id number: 2159220.
# ------------
# Retrieving results for kurumkan, ru (country code).
# City id number: 2021188.
# ------------
# Retrieving results for duku, ng (country code).
# City id number: 2344415.
# ------------
# Retrieving results for wulanhaote, cn (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for hofn, is (country code).
# City id number: 2630299.
# ------------
# Retrieving results for ipueiras, br (country code).
# City id number: 3392742.
# ------------
# Retrieving results for weihe, cn (country code).
# City id number: 7372400.
# ------------
# Retrieving results for aflu, dz (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for kongwa, tz (country code).
# City id number: 156493.
# ------------
# Retrieving results for tagusao, ph (country code).
# City id number: 1684245.
# ------------
# Retrieving results for daru, pg (country code).
# City id number: 2098329.
# ------------
# Retrieving results for nome, us (country code).
# City id number: 4732862.
# ------------
# Retrieving results for sitka, us (country code).
# City id number: 4267710.
# ------------
# Retrieving results for kapit, my (country code).
# City id number: 1737185.
# ------------
# Retrieving results for adrar, dz (country code).
# City id number: 2508813.
# ------------
# Retrieving results for meyungs, pw (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for baykit, ru (country code).
# City id number: 1510689.
# ------------
# Retrieving results for vaitupu, wf (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for liverpool, ca (country code).
# City id number: 6057856.
# ------------
# Retrieving results for verkhnevilyuysk, ru (country code).
# City id number: 2013639.
# ------------
# Retrieving results for wladyslawowo, pl (country code).
# City id number: 3081752.
# ------------
# Retrieving results for sobolevo, ru (country code).
# City id number: 525426.
# ------------
# Retrieving results for nguiu, au (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for alyangula, au (country code).
# City id number: 2079582.
# ------------
# Retrieving results for guerrero, mx (country code).
# City id number: 3524374.
# ------------
# Retrieving results for santa rosa, ar (country code).
# City id number: 3835994.
# ------------
# Retrieving results for shingu, jp (country code).
# City id number: 1847947.
# ------------
# Retrieving results for niceville, us (country code).
# City id number: 4165995.
# ------------
# Retrieving results for paradwip, in (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for biltine, td (country code).
# City id number: 244878.
# ------------
# Retrieving results for motegi, jp (country code).
# City id number: 2111827.
# ------------
# Retrieving results for pinotepa nacional, mx (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for sisimiut, gl (country code).
# City id number: 3419842.
# ------------
# Retrieving results for mahajanga, mg (country code).
# City id number: 1062663.
# ------------
# Retrieving results for dingle, ie (country code).
# City id number: 2964782.
# ------------
# Retrieving results for arenapolis, br (country code).
# City id number: 3471551.
# ------------
# Retrieving results for kalemie, cd (country code).
# City id number: 214974.
# ------------
# Retrieving results for cap-aux-meules, ca (country code).
# City id number: 5915327.
# ------------
# Retrieving results for marzuq, ly (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for kununurra, au (country code).
# City id number: 2068110.
# ------------
# Retrieving results for aleksandrovskoye, ru (country code).
# City id number: 1511846.
# ------------
# Retrieving results for priargunsk, ru (country code).
# City id number: 2017646.
# ------------
# Retrieving results for ilheus, br (country code).
# City id number: 3461408.
# ------------
# Retrieving results for sinnamary, gf (country code).
# City id number: 3380290.
# ------------
# Retrieving results for inhambane, mz (country code).
# City id number: 1045114.
# ------------
# Retrieving results for soure, br (country code).
# City id number: 3387204.
# ------------
# Retrieving results for cidreira, br (country code).
# City id number: 3466165.
# ------------
# Retrieving results for xadani, mx (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for takaka, nz (country code).
# City id number: 2181997.
# ------------
# Retrieving results for lima, pe (country code).
# City id number: 3936456.
# ------------
# Retrieving results for saint-joseph, re (country code).
# City id number: 6690296.
# ------------
# Retrieving results for lakatoro, vu (country code).
# City id number: 2136697.
# ------------
# Retrieving results for mino, jp (country code).
# City id number: 1857062.
# ------------
# Retrieving results for constitucion, mx (country code).
# City id number: 4011743.
# ------------
# Retrieving results for filadelfia, py (country code).
# City id number: 3867291.
# ------------
# Retrieving results for bien hoa, vn (country code).
# City id number: 1587923.
# ------------
# Retrieving results for madang, pg (country code).
# City id number: 2091996.
# ------------
# Retrieving results for gberia fotombu, sl (country code).
# City id number: 2409019.
# ------------
# Retrieving results for petropavlovsk-kamchatskiy, ru (country code).
# City id number: 2122104.
# ------------
# Retrieving results for shakawe, bw (country code).
# City id number: 933077.
# ------------
# Retrieving results for panara, in (country code).
# City id number: 1260600.
# ------------
# Retrieving results for karaul, ru (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for penzance, gb (country code).
# City id number: 2640377.
# ------------
# Retrieving results for ewo, cg (country code).
# City id number: 2260009.
# ------------
# Retrieving results for camacha, pt (country code).
# City id number: 2270385.
# ------------
# Retrieving results for urman, ru (country code).
# City id number: 478699.
# ------------
# Retrieving results for port augusta, au (country code).
# City id number: 2063056.
# ------------
# Retrieving results for shelburne, ca (country code).
# City id number: 6145890.
# ------------
# Retrieving results for acapulco, mx (country code).
# City id number: 3533462.
# ------------
# Retrieving results for pitea, se (country code).
# City id number: 603570.
# ------------
# Retrieving results for ous, ru (country code).
# City id number: 1495812.
# ------------
# Retrieving results for toora-khem, ru (country code).
# City id number: 1489401.
# ------------
# Retrieving results for ugoofaaru, mv (country code).
# City id number: 1337619.
# ------------
# Retrieving results for villa del rosario, ve (country code).
# City id number: 3628966.
# ------------
# Retrieving results for kyren, ru (country code).
# City id number: 2021031.
# ------------
# Retrieving results for cortez, us (country code).
# City id number: 5418104.
# ------------
# Retrieving results for bathsheba, bb (country code).
# City id number: 3374083.
# ------------
# Retrieving results for zabalj, rs (country code).
# City id number: 784068.
# ------------
# Retrieving results for kirkwall, gb (country code).
# City id number: 2645198.
# ------------
# Retrieving results for pafos, cy (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for imbituba, br (country code).
# City id number: 3461370.
# ------------
# Retrieving results for port hardy, ca (country code).
# City id number: 6111862.
# ------------
# Retrieving results for salta, ar (country code).
# City id number: 3838233.
# ------------
# Retrieving results for passo de camaragibe, br (country code).
# City id number: 3388341.
# ------------
# Retrieving results for ust-maya, ru (country code).
# City id number: 2013918.
# ------------
# Retrieving results for kandi, bj (country code).
# City id number: 2393693.
# ------------
# Retrieving results for suntar, ru (country code).
# City id number: 2015913.
# ------------
# Retrieving results for hartford, us (country code).
# City id number: 4835797.
# ------------
# Retrieving results for hay river, ca (country code).
# City id number: 5972762.
# ------------
# Retrieving results for jacmel, ht (country code).
# City id number: 3723779.
# ------------
# Retrieving results for bemidji, us (country code).
# City id number: 5017822.
# ------------
# Retrieving results for dhidhdhoo, mv (country code).
# City id number: 1337612.
# ------------
# Retrieving results for andenes, no (country code).
# City id number: 3163146.
# ------------
# Retrieving results for paraiso, mx (country code).
# City id number: 4011743.
# ------------
# Retrieving results for fairbanks, us (country code).
# City id number: 5861897.
# ------------
# Retrieving results for deputatskiy, ru (country code).
# City id number: 2028164.
# ------------
# Retrieving results for henties bay, na (country code).
# City id number: 3356832.
# ------------
# Retrieving results for sibu, my (country code).
# City id number: 1735902.
# ------------
# Retrieving results for myitkyina, mm (country code).
# City id number: 1307741.
# ------------
# Retrieving results for ialibu, pg (country code).
# City id number: 2095925.
# ------------
# Retrieving results for iqaluit, ca (country code).
# City id number: 5983720.
# ------------
# Retrieving results for gasa, bt (country code).
# City id number: 1252578.
# ------------
# Retrieving results for takoradi, gh (country code).
# City id number: 2294915.
# ------------
# Retrieving results for dunedin, nz (country code).
# City id number: 2191562.
# ------------
# Retrieving results for san cristobal, ec (country code).
# City id number: 3652567.
# ------------
# Retrieving results for pirovskoye, ru (country code).
# City id number: 1494941.
# ------------
# Retrieving results for banda aceh, id (country code).
# City id number: 1215502.
# ------------
# Retrieving results for sassandra, ci (country code).
# City id number: 2281951.
# ------------
# Retrieving results for gore, et (country code).
# City id number: 335943.
# ------------
# Retrieving results for sioux lookout, ca (country code).
# City id number: 6148373.
# ------------
# Retrieving results for khatanga, ru (country code).
# City id number: 2022572.
# ------------
# Retrieving results for vega de alatorre, mx (country code).
# City id number: 3514843.
# ------------
# Retrieving results for bambanglipuro, id (country code).
# City id number: 1650434.
# ------------
# Retrieving results for chhatak, bd (country code).
# City id number: 1185254.
# ------------
# Retrieving results for makubetsu, jp (country code).
# City id number: 2128815.
# ------------
# Retrieving results for cayenne, gf (country code).
# City id number: 3382160.
# ------------
# Retrieving results for banjar, id (country code).
# City id number: 1650233.
# ------------
# Retrieving results for dodge city, us (country code).
# City id number: 5445298.
# ------------
# Retrieving results for catio, gw (country code).
# City id number: 2373526.
# ------------
# Retrieving results for mulege, mx (country code).
# City id number: 3995236.
# ------------
# Retrieving results for ust-nera, ru (country code).
# City id number: 2120048.
# ------------
# Retrieving results for tabiauea, ki (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for marcona, pe (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for opuwo, na (country code).
# City id number: 3354077.
# ------------
# Retrieving results for straumen, no (country code).
# City id number: 3135728.
# ------------
# Retrieving results for guane, cu (country code).
# City id number: 3557758.
# ------------
# Retrieving results for linden, gy (country code).
# City id number: 3377408.
# ------------
# Retrieving results for mandalgovi, mn (country code).
# City id number: 2030065.
# ------------
# Retrieving results for hambantota, lk (country code).
# City id number: 1244926.
# ------------
# Retrieving results for porbandar, in (country code).
# City id number: 1259395.
# ------------
# Retrieving results for yenotayevka, ru (country code).
# City id number: 467479.
# ------------
# Retrieving results for iberia, pe (country code).
# City id number: 3938531.
# ------------
# Retrieving results for clyde river, ca (country code).
# City id number: 5924351.
# ------------
# Retrieving results for sokoni, tz (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for hami, cn (country code).
# City id number: 1529484.
# ------------
# Retrieving results for aklavik, ca (country code).
# City id number: 5882953.
# ------------
# Retrieving results for gravdal, no (country code).
# City id number: 3147822.
# ------------
# Retrieving results for ordu, tr (country code).
# City id number: 741100.
# ------------
# Retrieving results for sao gabriel da cachoeira, br (country code).
# City id number: 3662342.
# ------------
# Retrieving results for rockport, us (country code).
# City id number: 4723422.
# ------------
# Retrieving results for vardo, no (country code).
# City id number: 777019.
# ------------
# Retrieving results for fallon, us (country code).
# City id number: 5681948.
# ------------
# Retrieving results for eldikan, ru (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for isangel, vu (country code).
# City id number: 2136825.
# ------------
# Retrieving results for burley, us (country code).
# City id number: 5587385.
# ------------
# Retrieving results for muros, es (country code).
# City id number: 3115824.
# ------------
# Retrieving results for naze, jp (country code).
# City id number: 1855540.
# ------------
# Retrieving results for mildura, au (country code).
# City id number: 2157698.
# ------------
# Retrieving results for anan, jp (country code).
# City id number: 1865309.
# ------------
# Retrieving results for novovarshavka, ru (country code).
# City id number: 1496633.
# ------------
# Retrieving results for ambulu, id (country code).
# City id number: 1621313.
# ------------
# Retrieving results for ixtapa, mx (country code).
# City id number: 4004293.
# ------------
# Retrieving results for karsun, ru (country code).
# City id number: 552133.
# ------------
# Retrieving results for fonte boa, br (country code).
# City id number: 3664207.
# ------------
# Retrieving results for san carlos de bariloche, ar (country code).
# City id number: 7647007.
# ------------
# Retrieving results for buariki, ki (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for khandagayty, ru (country code).
# City id number: 1503796.
# ------------
# Retrieving results for luanda, ao (country code).
# City id number: 2240449.
# ------------
# Retrieving results for kitimat, ca (country code).
# City id number: 5993072.
# ------------
# Retrieving results for patu, br (country code).
# City id number: 3392862.
# ------------
# Retrieving results for saint-ambroise, ca (country code).
# City id number: 6137381.
# ------------
# Retrieving results for chimbote, pe (country code).
# City id number: 3698304.
# ------------
# Retrieving results for jalu, ly (country code).
# City id number: 86049.
# ------------
# Retrieving results for bilibino, ru (country code).
# City id number: 2126682.
# ------------
# Retrieving results for la palma, pa (country code).
# City id number: 3707058.
# ------------
# Retrieving results for mairena del alcor, es (country code).
# City id number: 2514288.
# ------------
# Retrieving results for batagay, ru (country code).
# City id number: 2027044.
# ------------
# Retrieving results for kindberg, at (country code).
# City id number: 2774437.
# ------------
# Retrieving results for urumqi, cn (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for ponta delgada, pt (country code).
# City id number: 3372783.
# ------------
# Retrieving results for mogadishu, so (country code).
# City id number: 53654.
# ------------
# Retrieving results for comodoro rivadavia, ar (country code).
# City id number: 3860443.
# ------------
# Retrieving results for sabha, ly (country code).
# City id number: 2212775.
# ------------
# Retrieving results for san lorenzo, bo (country code).
# City id number: 3907080.
# ------------
# Retrieving results for palmas, br (country code).
# City id number: 3474574.
# ------------
# Retrieving results for vaitape, pf (country code).
# City id number: 4033077.
# ------------
# Retrieving results for kamina, cd (country code).
# City id number: 214614.
# ------------
# Retrieving results for borculo, nl (country code).
# City id number: 2758626.
# ------------
# Retrieving results for samarai, pg (country code).
# City id number: 2132606.
# ------------
# Retrieving results for grand river south east, mu (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for mackenzie, ca (country code).
# City id number: 6063191.
# ------------
# Retrieving results for rosarito, mx (country code).
# City id number: 3980161.
# ------------
# Retrieving results for kismayo, so (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for lar, ir (country code).
# City id number: 133595.
# ------------
# Retrieving results for anloga, gh (country code).
# City id number: 2304548.
# ------------
# Retrieving results for olga, ru (country code).
# City id number: 2018553.
# ------------
# Retrieving results for vostok, ru (country code).
# City id number: 2013279.
# ------------
# Retrieving results for weyburn, ca (country code).
# City id number: 6179652.
# ------------
# Retrieving results for angoche, mz (country code).
# City id number: 1052944.
# ------------
# Retrieving results for kilindoni, tz (country code).
# City id number: 157429.
# ------------
# Retrieving results for puerto escondido, mx (country code).
# City id number: 3520994.
# ------------
# Retrieving results for rudnyy, ru (country code).
# City id number: 2017377.
# ------------
# Retrieving results for minab, ir (country code).
# City id number: 123941.
# ------------
# Retrieving results for kirando, tz (country code).
# City id number: 157107.
# ------------
# Retrieving results for tlahualilo, mx (country code).
# Missing field/result... skipping.
# ------------
# Retrieving results for corinto, ni (country code).
# City id number: 3620269.
# ------------
# Retrieving results for mbeya, tz (country code).
# City id number: 154380.
# ------------
# Retrieving results for chichli, in (country code).
# City id number: 1274267.
# ------------
# Retrieving results for tazovskiy, ru (country code).
# City id number: 1489853.
# ------------
# Retrieving results for hervey bay, au (country code).
# City id number: 2146219.
# ------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Visualize dataframe
weather_df.head(20)
# Out:
#               city country       id latitude longitude temp_f humidity  \
# 0              oda      jp  1854774    35.19     132.5   49.9       97
# 1   kumylzhenskaya      ru   539221    49.88     42.59  31.71       94
# 2             mana      gf  3381041     5.67    -53.78  81.22       66
# 3           avarua      ck  4035715   -21.21   -159.78   80.6       94
# 4        cape town      za  3369157   -33.93     18.42  65.79       88
# 5         tasiilaq      gl  3424607    65.61    -37.64   21.2       67
# 6            cesis      lv   460570    57.31     25.27  35.04       74
# 7           domoni      km   921906   -12.26     44.53  85.18      100
# 8          bairiki      ki
# 9   ribeira grande      pt  3372707    38.52     -28.7     59       72
# 10           kapaa      us  5848280    22.08   -159.32  71.92       78
# 11           vaini      to  4032243    -21.2    -175.2     77       78
# 12         rikitea      pf  4030556   -23.12   -134.97  78.97       99
# 13          moyale      et   186180     3.52     39.05  71.59       67
# 14        portland      au  2152668   -33.35    149.98  59.05       95
# 15          albany      au  2077963   -35.02    117.88   55.4       71
# 16         aloleng      ph  1731298    16.13    119.78  77.08       89
# 17         qaanaaq      gl  3831208    77.48    -69.36 -20.66       86
# 18  port elizabeth      za   964420   -33.92     25.57   71.6       88
# 19         huarmey      pe  3939168   -10.07    -78.15  75.64       63
#
#    cloudiness wind_speed        date
# 0          88      12.97  1553459621
# 1           0       6.93  1553459604
# 2          88        4.7  1553459622
# 3          80       6.93  1553457600
# 4           0      13.87  1553459445
# 5          92      25.28  1553457000
# 6          20          4  1553459439
# 7          88       6.38  1553459624
# 8
# 9          20       8.05  1553457600
# 10         90      11.41  1553459605
# 11         75       9.17  1553457600
# 12         64      13.76  1553459621
# 13          8       5.37  1553459626
# 14         80       8.99  1553459586
# 15         90       3.36  1553457600
# 16          0      11.18  1553459627
# 17          0       8.05  1553459627
# 18         75      16.11  1553457600
# 19         36       3.58  1553459628

# %%
# Clean data
weather_clean = weather_df

# Replace blanks with NaN
weather_clean.replace('', np.nan, inplace=True)

# Delete rows with NaNs
weather_clean.dropna(subset=["latitude", "longitude", "temp_f", "humidity", "cloudiness", "wind_speed"], inplace=True)

print(weather_clean.count())

# Save dataframe to csv
weather_clean.to_csv("cities_weather.csv", index=False, header=True)
# Out:
# city          522
# country       522
# id            522
# latitude      522
# longitude     522
# temp_f        522
# humidity      522
# cloudiness    522
# wind_speed    522
# date          522
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Set x and y axes
x_axis = weather_clean["latitude"]
y_temp = weather_clean["temp_f"]
plt.scatter(x_axis, y_temp, marker="o", c=y_temp, edgecolors="grey", cmap='coolwarm')

# Format chart
plt.title("City Temperature by Latitude")
plt.xlabel("Latitude")
plt.ylabel("Current Temperature (F)")
plt.grid(True)
plt.axvline(0, color = 'black', alpha = 0.5, label = 'Equator') #adds equator line
plt.text(1,30,'Equator',rotation=90)
plt.xlim([-60, 80])
plt.ylim([-30, 100])

# Save figure
plt.savefig("temp_lat.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Set y axis (x is the same for all plots)
y_hum = weather_clean["humidity"]
plt.scatter(x_axis, y_hum, marker="o", c=y_hum, edgecolors="grey", cmap='YlGnBu')

# Format chart
plt.title("City Humidity by Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.axvline(0, color = 'black', alpha = 0.5, label = 'Equator') #adds equator line
plt.text(1,30,'Equator',rotation=90)
plt.xlim([-60, 80])
plt.ylim([5, 105])

# Save figure
plt.savefig("humidity_lat.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Set y axis (x is the same for all plots)
y_clouds = weather_clean["cloudiness"]
plt.scatter(x_axis, y_clouds, marker="o", c=y_clouds, edgecolors="grey", cmap='pink')

# Format chart
plt.title("City Cloudiness by Latitude")
plt.xlabel("Latitude")
plt.ylabel("# of Clouds")
plt.grid(True)
plt.axvline(0, color = 'black', alpha = 0.5, label = 'Equator') #adds equator line
plt.text(1,30,'Equator',rotation=90)
plt.xlim([-60, 80])
plt.ylim([-5, 105])

# Save figure
plt.savefig("clouds_lat.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Set y axis (x is the same for all plots)
y_wind = weather_clean["wind_speed"]
plt.scatter(x_axis, y_wind, marker="o", c=y_wind, edgecolors="grey", cmap='Set2')

# Format chart
plt.title("City Wind Speed by Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.axvline(0, color = 'black', alpha = 0.5, label = 'Equator') #adds equator line
plt.text(1,30,'Equator',rotation=90)
plt.xlim([-60, 80])
plt.ylim([0, 55])

# Save figure
plt.savefig("wind_lat.png")

# Show plot
plt.show()

# %% [markdown]
# Observations:
#     1) There's a clear relationship between temperature and the equator. Cities closest to the equator experience the highest temperatures, and cities farthest away from the equator experience the coolest temperatures.
#     2) There doesn't appear to be a relationship between moisture (cloudiness and humidity) and proximity to the equator.
#     3) While most cities appear to appear to experience wind speeds of between 0 and 15 mph, regardless of how close they are to the equator, the occasional extremes (wind speeds above 20 mph), appear to mainly occur father away from the equator (below -20 or above 40 degrees).
